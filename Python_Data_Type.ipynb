# %% [markdown]
# # Data Types

# %%
name = 'Amit' #string (str)
age = 25 # integer (int)
bank_balance = 20000.4 #float

# %%
info = ['Amit',25 ,2000.5]  # list

# %%
print(info)
# Out:
# ['Amit', 25, 2000.5]

# %% [markdown]
# # Indexing

# %%
info[0] # display the element from a particular index number.
# Out:
# 'Amit'

# %% [markdown]
# # Memory identify for  values

# %%
print(name)
# Out:
# Amit

# %% [markdown]
# id function use to memory (storage value)

# %%
id(name)
# Out:
# 135431541166832

# %%
id(age)
# Out:
# 10751624

# %% [markdown]
# help function use for discrbie others functions

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(id)
# Out:
# Help on built-in function id in module builtins:
#
# id(obj, /)
#     Return the identity of an object.
#
#     This is guaranteed to be unique among simultaneously existing objects.
#     (CPython uses the object's memory address.)

# %% [markdown]
# ## Dictionary
#
# Dictionary is a set of key:value pair(s)

# %%
info1 ={}

# %%
type(info1) # type function are use to discribe to data type
# Out:
# dict

# %%
info1 = {name :'Amit', age : 25 , bank_balance : 20000.4} # dict is a set of key:value pairs

# %%
info1[name]
# Out:
# 'Amit'

# %%
info1[age]
# Out:
# 25

# %%
a = 10 # int
b = 25.5 # float
name = "Allen" # str
lst = [10,25.5, 'Allen'] # list
dic = {'a':10,'b':25.5,'name':'Allen'} #dict

# %%
type(a)
# Out:
# int

# %%
print('c:\docs\navin') #\n use for new line
# Out:
# c:\docs
# avin

# %%
print(r'c:\docs\navin') # r function use for represent as it
# Out:
# c:\docs\navin

# %% [markdown]
# # How to store data in datatype

# %% [markdown]
# *  int (integer)
# *  float

# %%
a = 10
b = 25.7

# %% [markdown]
#   * str (string)

# %% [markdown]
# string can content  numbers,charecters,spical char,spaces.

# %%
name = 'Amit'
password = 'Hello123$'
name2 = 'Amit Patil'

# %% [markdown]
# ##  Collections

# %% [markdown]
# *   List
# *   dict(dictionary)
# *   tuple
# *   set

# %%
lst = [] # notatio [] =list
d = {}  # notation {} = set - set is collectio of unique values
d1 = {} # notation {} = dict - key:value pair its a dictionary

# %%
lst = [1,2,3]
d = {1,2,3,'Amit'}
d1 = {'name':'Amit'} # key:value pair its a dictionary

# %%
type(lst)
# Out:
# list

# %%
type(d)
# Out:
# set

# %%
type(d1)
# Out:
# dict

# %% [markdown]
# *  list allow duplicate
# *  set does not allow duplicate

# %%
s = {1,2,3,4,5,5} # set

# %%
print(s) # set does not allow duplicates
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 =  { 5,4,3,2,1}

# %%
s1 # set allowes print / show ascending order
# Out:
# {1, 2, 3, 4, 5}

# %%
x = [1,2,3,4,5,5 ] #list

# %%
print(x) # list allow dupliactes
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
# dict (dictionary) key : value pair based concept , key must be unique
d2 = {'name':'Amit' ,'name':'sumit' ,'age':25,'name':'Allen'} # name is  override

# %%
d2
# Out:
# {'name': 'Allen', 'age': 25}

# %%
d2['age'] # we can  select specific value based on key
# Out:
# 25

# %% [markdown]
# *  Tuple
#
# Notation = ()
#
# tuple allows duplicates , tuple doesn't allow any changes

# %%
 t = (1,2,3) # tuple allows duplicates

# %%
type(t)
# Out:
# tuple

# %%
print(t)
# Out:
# (1, 2, 3)

# %%
t[0]
# Out:
# 1

# %%
t[0] =100 #tuple doesn't allow any changes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-3b87140ec868> in <cell line: 0>()
# ----> 1 t[0] =100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # NoneType is the name of datatype, and it contains value as None

# %%
dummy = None

# %%
type(dummy)
# Out:
# NoneType

# %%
aa1 =
# Out:
#   File "<ipython-input-60-293026337aeb>", line 1
#     aa1 =
#          ^
# SyntaxError: invalid syntax
